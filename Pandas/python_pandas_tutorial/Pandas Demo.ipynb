# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 50)

# %%
na_vals = ['NA', 'Missing']
df = pd.read_csv('data/survey_results_public.csv', index_col='ResponseId', na_values=na_vals)

# %%
df
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
# ...                                                       ...
# 83435                          I am a developer by profession
# 83436                          I am a developer by profession
# 83437                          I am a developer by profession
# 83438                          I am a developer by profession
# 83439                          I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# ...

# %%
df.shape
# Out:
# (83439, 47)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 83439 entries, 1 to 83439
# Data columns (total 47 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   MainBranch                    83439 non-null  object
#  1   Employment                    83323 non-null  object
#  2   Country                       83439 non-null  object
#  3   US_State                      14920 non-null  object
#  4   UK_Country                    4418 non-null   object
#  5   EdLevel                       83126 non-null  object
#  6   Age1stCode                    83243 non-null  object
#  7   LearnCode                     82963 non-null  object
#  8   YearsCode                     81641 non-null  object
#  9   YearsCodePro                  61216 non-null  object
#  10  DevType                       66484 non-null  object
#  11  OrgSize                       60726 non-null  object
# ...

# %%
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='qname')

# %%
schema_df
# Out:
#                        qid                                           question  \
# qname
# S0                   QID16  <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo             QID12                                  Browser Meta Info
# S1                    QID1  <span style="font-size:22px; font-family: aria...
# MainBranch            QID2  Which of the following options best describes ...
# Employment           QID24  Which of the following best describes your cur...
# Country               QID6  Where do you live? <span style="font-weight: b...
# US_State              QID7  <p>In which state or territory of the USA do y...
# UK_Country            QID9  In which part of the United Kingdom do you liv...
# S2                  QID190  <span style="font-size:22px; font-family: aria...
# EdLevel              QID25  Which of the following best describes the high...
# Age1stCode          QID149  At what age did you write your first line of c...
# ...

# %%
df.head()
# Out:
#                                                    MainBranch  \
# ResponseId
# 1                              I am a developer by profession
# 2                      I am a student who is learning to code
# 3           I am not primarily a developer, but I write co...
# 4                              I am a developer by profession
# 5                              I am a developer by profession
#
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# 3                                          Student, full-time
# 4                                          Employed full-time
# 5           Independent contractor, freelancer, or self-em...
#
#                                                       Country US_State  \
# ResponseId
# 1                                                    Slovakia      NaN
# ...

# %%
df.columns
# Out:
# Index(['MainBranch', 'Employment', 'Country', 'US_State', 'UK_Country',
#        'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode', 'YearsCodePro',
#        'DevType', 'OrgSize', 'Currency', 'CompTotal', 'CompFreq',
#        'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
df['Employment']
# Out:
# ResponseId
# 1        Independent contractor, freelancer, or self-em...
# 2                                       Student, full-time
# 3                                       Student, full-time
# 4                                       Employed full-time
# 5        Independent contractor, freelancer, or self-em...
#                                ...
# 83435                                   Employed full-time
# 83436    Independent contractor, freelancer, or self-em...
# 83437                                   Employed full-time
# 83438                                   Employed full-time
# 83439                                   Employed full-time
# Name: Employment, Length: 83439, dtype: object

# %%
df.loc[0:10, 'Employment':'EdLevel']
# Out:
#                                                    Employment  \
# ResponseId
# 1           Independent contractor, freelancer, or self-em...
# 2                                          Student, full-time
# 3                                          Student, full-time
# 4                                          Employed full-time
# 5           Independent contractor, freelancer, or self-em...
# 6                                          Student, part-time
# 7                                         I prefer not to say
# 8                                          Student, full-time
# 9                                          Employed part-time
# 10                                         Employed full-time
#
#                                                       Country       US_State  \
# ResponseId
# 1                                                    Slovakia            NaN
# 2                                                 Netherlands            NaN
# ...

# %%
schema_df.loc['SOComm', 'question']
# Out:
# 'Do you consider yourself a member of the Stack Overflow community?'

# %%
schema_df.sort_index(ascending=True, inplace=True)
schema_df
# Out:
#                        qid                                           question  \
# qname
# Accessibility       QID124  Which of the following describe you, if any? P...
# Age                 QID127                                  What is your age?
# Age1stCode          QID149  At what age did you write your first line of c...
# CompFreq             QID52   Is that compensation weekly, monthly, or yearly?
# CompTotal            QID51  What is your current total compensation (salar...
# Country               QID6  Where do you live? <span style="font-weight: b...
# Currency             QID50  Which currency do you use day-to-day? If your ...
# Database            QID262  Which <b>database environments </b>have you do...
# DevType              QID31  Which of the following describes your current ...
# EdLevel              QID25  Which of the following best describes the high...
# Employment           QID24  Which of the following best describes your cur...
# ...

# %% [markdown]
# ### Filtering - Using Conditionals to Filter Rows and Columns

# %%
china_high_salary = (df['Country'] == 'China') & (df['CompTotal'] > 500000)

# %%
df.loc[china_high_salary, ['Country', 'Age1stCode', 'LearnCode', 'CompTotal']]
# Out:
#            Country            Age1stCode  \
# ResponseId
# 11079        China         18 - 24 years
# 11083        China         11 - 17 years
# 12037        China         18 - 24 years
# 12133        China          5 - 10 years
# 19343        China          5 - 10 years
# 20465        China         35 - 44 years
# 21956        China         18 - 24 years
# 23535        China         11 - 17 years
# 32477        China          5 - 10 years
# 36184        China         11 - 17 years
# 39627        China         11 - 17 years
# 41343        China         18 - 24 years
# 41471        China         11 - 17 years
# 41759        China         11 - 17 years
# 44510        China         25 - 34 years
# 44706        China         18 - 24 years
# 44710        China         35 - 44 years
# 49899        China         35 - 44 years
# 56972        China         11 - 17 years
# 63560        China         25 - 34 years
# 64507        China         11 - 17 years
# ...

# %%
countries = ["United States of America", "China", "India", "Canada"]
filt = df["Country"].isin(countries)

# %%
df.loc[filt, "Country"]
# Out:
# ResponseId
# 6        United States of America
# 7        United States of America
# 9                           India
# 16       United States of America
# 18                         Canada
#                    ...
# 83431    United States of America
# 83433                      Canada
# 83435    United States of America
# 83437    United States of America
# 83438                      Canada
# Name: Country, Length: 29866, dtype: object

# %%
filt = df['LanguageHaveWorkedWith'].str.contains("Python", na=False)

# %%
df.loc[filt, 'LanguageHaveWorkedWith']
# Out:
# ResponseId
# 2                                        JavaScript;Python
# 3                                 Assembly;C;Python;R;Rust
# 5                           Bash/Shell;HTML/CSS;Python;SQL
# 6        C;C#;C++;HTML/CSS;Java;JavaScript;Node.js;Powe...
# 10                                              C++;Python
#                                ...
# 83430               HTML/CSS;PHP;PowerShell;Python;SQL;VBA
# 83431          APL;Clojure;LISP;Python;Ruby;SQL;TypeScript
# 83432    C#;Dart;HTML/CSS;Java;JavaScript;Kotlin;Node.j...
# 83437                                   Groovy;Java;Python
# 83438                 Bash/Shell;JavaScript;Node.js;Python
# Name: LanguageHaveWorkedWith, Length: 39792, dtype: object

# %% [markdown]
# ### Updating Rows and Columns - Modifying Data Within DataFrames

# %%
df.rename(columns={'ConvertedCompYearly': 'SalaryYearly'}, inplace=True)

# %%
df['SalaryYearly']
# Out:
# ResponseId
# 1         62268.0
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
#            ...
# 83435    160500.0
# 83436      3960.0
# 83437     90000.0
# 83438    816816.0
# 83439     21168.0
# Name: SalaryYearly, Length: 83439, dtype: float64

# %%
df['SOAccount'].replace({'Yes': True, 'No': False, 'nan': False, 'NaN': False})
# Out:
# ResponseId
# 1         True
# 2         True
# 3         True
# 4         True
# 5         True
#          ...
# 83435    False
# 83436     True
# 83437     True
# 83438     True
# 83439     True
# Name: SOAccount, Length: 83439, dtype: object

# %%
df['MainBranch'] = df['MainBranch'].str.upper()
df['MainBranch']
# Out:
# ResponseId
# 1                           I AM A DEVELOPER BY PROFESSION
# 2                   I AM A STUDENT WHO IS LEARNING TO CODE
# 3        I AM NOT PRIMARILY A DEVELOPER, BUT I WRITE CO...
# 4                           I AM A DEVELOPER BY PROFESSION
# 5                           I AM A DEVELOPER BY PROFESSION
#                                ...
# 83435                       I AM A DEVELOPER BY PROFESSION
# 83436                       I AM A DEVELOPER BY PROFESSION
# 83437                       I AM A DEVELOPER BY PROFESSION
# 83438                       I AM A DEVELOPER BY PROFESSION
# 83439                       I AM A DEVELOPER BY PROFESSION
# Name: MainBranch, Length: 83439, dtype: object

# %%
df['MainBranch'].apply(len)
# Out:
# ResponseId
# 1        30
# 2        38
# 3        77
# 4        30
# 5        30
#          ..
# 83435    30
# 83436    30
# 83437    30
# 83438    30
# 83439    30
# Name: MainBranch, Length: 83439, dtype: int64

# %%
def lower_mainbranch(mainbranch):
    return mainbranch.lower()
df['MainBranch'] = df['MainBranch'].apply(lower_mainbranch)
df['MainBranch']
# Out:
# ResponseId
# 1                           i am a developer by profession
# 2                   i am a student who is learning to code
# 3        i am not primarily a developer, but i write co...
# 4                           i am a developer by profession
# 5                           i am a developer by profession
#                                ...
# 83435                       i am a developer by profession
# 83436                       i am a developer by profession
# 83437                       i am a developer by profession
# 83438                       i am a developer by profession
# 83439                       i am a developer by profession
# Name: MainBranch, Length: 83439, dtype: object

# %%
df['MainBranch'] = df['MainBranch'].apply(lambda x: x.upper())
df['MainBranch']
# Out:
# ResponseId
# 1                           I AM A DEVELOPER BY PROFESSION
# 2                   I AM A STUDENT WHO IS LEARNING TO CODE
# 3        I AM NOT PRIMARILY A DEVELOPER, BUT I WRITE CO...
# 4                           I AM A DEVELOPER BY PROFESSION
# 5                           I AM A DEVELOPER BY PROFESSION
#                                ...
# 83435                       I AM A DEVELOPER BY PROFESSION
# 83436                       I AM A DEVELOPER BY PROFESSION
# 83437                       I AM A DEVELOPER BY PROFESSION
# 83438                       I AM A DEVELOPER BY PROFESSION
# 83439                       I AM A DEVELOPER BY PROFESSION
# Name: MainBranch, Length: 83439, dtype: object

# %%
# apply func, works on each Series
df.apply(len)
# Out:
# MainBranch                      83439
# Employment                      83439
# Country                         83439
# US_State                        83439
# UK_Country                      83439
# EdLevel                         83439
# Age1stCode                      83439
# LearnCode                       83439
# YearsCode                       83439
# YearsCodePro                    83439
# DevType                         83439
# OrgSize                         83439
# Currency                        83439
# CompTotal                       83439
# CompFreq                        83439
# LanguageHaveWorkedWith          83439
# LanguageWantToWorkWith          83439
# DatabaseHaveWorkedWith          83439
# DatabaseWantToWorkWith          83439
# PlatformHaveWorkedWith          83439
# PlatformWantToWorkWith          83439
# WebframeHaveWorkedWith          83439
# WebframeWantToWorkWith          83439
# MiscTechHaveWorkedWith          83439
# MiscTechWantToWorkWith          83439
# ...

# %%
df.apply(len, axis='columns')
# Out:
# ResponseId
# 1        47
# 2        47
# 3        47
# 4        47
# 5        47
#          ..
# 83435    47
# 83436    47
# 83437    47
# 83438    47
# 83439    47
# Length: 83439, dtype: int64

# %%
len(df['MainBranch'])
# Out:
# 83439

# %%
df2 = pd.DataFrame([[9, 3, 4], [4, 5, 2], [7, 1, 3], [10, 7, 2]])
df2
# Out:
#     0  1  2
# 0   9  3  4
# 1   4  5  2
# 2   7  1  3
# 3  10  7  2

# %%
df2.apply(pd.Series.min)
# Out:
# 0    4
# 1    1
# 2    2
# dtype: int64

# %%
# applymap func, works on each Element, Series dont have applymap func
df2.applymap(lambda x: x*2)
# Out:
#     0   1  2
# 0  18   6  8
# 1   8  10  4
# 2  14   2  6
# 3  20  14  4

# %%
# map func only works on Series
df2[0].map({9:0, 4:0, 7:0})
# Out:
# 0    0.0
# 1    0.0
# 2    0.0
# 3    NaN
# Name: 0, dtype: float64

# %%
df2[0].replace({9:0, 4:0, 7:0})
# Out:
# 0     0
# 1     0
# 2     0
# 3    10
# Name: 0, dtype: int64

# %% [markdown]
# ### Add/Remove Rows and Columns From DataFrames

# %%
df2[0] + df2[1]
# Out:
# 0    12
# 1     9
# 2     8
# 3    17
# dtype: int64

# %%
df2['0+1'] = df2[0] + df2[1]

# %%
df2
# Out:
#     0  1  2  0+1
# 0   9  3  4   12
# 1   4  5  2    9
# 2   7  1  3    8
# 3  10  7  2   17

# %%
df2.drop(columns=[0, 1], inplace=True)

# %%
df2[0] = df2['0+1'].astype(str).apply(lambda x: x+'a')
df2.drop(index=3)
# Out:
#    2  0+1    0
# 0  4   12  12a
# 1  2    9   9a
# 2  3    8   8a

# %% [markdown]
# ### Sorting Data

# %%
df2.sort_values(by=2, ascending=False)
# Out:
#    2  0+1    0
# 0  4   12  12a
# 2  3    8   8a
# 1  2    9   9a
# 3  2   17  17a

# %%
df2.sort_values(by=[2, '0+1'], ascending=False)
# Out:
#    2  0+1    0
# 0  4   12  12a
# 2  3    8   8a
# 3  2   17  17a
# 1  2    9   9a

# %%
df2.sort_values(by=[2, '0+1'], ascending=[False, True], inplace=True)
df2
# Out:
#    2  0+1    0
# 0  4   12  12a
# 2  3    8   8a
# 1  2    9   9a
# 3  2   17  17a

# %%
df2.sort_index()
# Out:
#    2  0+1    0
# 0  4   12  12a
# 1  2    9   9a
# 2  3    8   8a
# 3  2   17  17a

# %%
df.sort_values(by=['Country', 'SalaryYearly'], ascending=[True, False], inplace=True)
df[['Country', 'SalaryYearly']]
# Out:
#                 Country  SalaryYearly
# ResponseId
# 65400       Afghanistan    30468516.0
# 22667       Afghanistan      155496.0
# 27199       Afghanistan       51804.0
# 31087       Afghanistan       23964.0
# 44641       Afghanistan       15132.0
# ...                 ...           ...
# 75694          Zimbabwe           NaN
# 76083          Zimbabwe           NaN
# 79302          Zimbabwe           NaN
# 80997          Zimbabwe           NaN
# 82407          Zimbabwe           NaN
#
# [83439 rows x 2 columns]

# %%
df['SalaryYearly'].nlargest(10)
# Out:
# ResponseId
# 66911    45241312.0
# 65400    30468516.0
# 40587    21822250.0
# 28792    20000000.0
# 12701    19200000.0
# 9609     17500000.0
# 5306     15000000.0
# 12904    14411628.0
# 66489    12750000.0
# 7206     12500000.0
# Name: SalaryYearly, dtype: float64

# %%
df.sort_values(by='SalaryYearly', ascending=False, inplace=True)
df[['SalaryYearly', 'LanguageHaveWorkedWith']].head(10)
# Out:
#             SalaryYearly                             LanguageHaveWorkedWith
# ResponseId
# 66911         45241312.0                                                APL
# 65400         30468516.0  Bash/Shell;C++;Elixir;LISP;Node.js;Ruby;Rust;S...
# 40587         21822250.0  Bash/Shell;HTML/CSS;Java;JavaScript;Node.js;Py...
# 28792         20000000.0  C#;C++;Groovy;HTML/CSS;Java;JavaScript;Node.js...
# 12701         19200000.0                                         JavaScript
# 9609          17500000.0  Bash/Shell;Go;HTML/CSS;Java;JavaScript;Kotlin;...
# 5306          15000000.0                                             Python
# 12904         14411628.0                       C#;JavaScript;Node.js;Python
# 66489         12750000.0  Bash/Shell;Go;HTML/CSS;Java;JavaScript;Kotlin;...
# 47564         12500000.0           Go;HTML/CSS;JavaScript;Python;TypeScript

# %%
df.nlargest(10, 'SalaryYearly')[['SalaryYearly', 'LanguageHaveWorkedWith']]
# Out:
#             SalaryYearly                             LanguageHaveWorkedWith
# ResponseId
# 66911         45241312.0                                                APL
# 65400         30468516.0  Bash/Shell;C++;Elixir;LISP;Node.js;Ruby;Rust;S...
# 40587         21822250.0  Bash/Shell;HTML/CSS;Java;JavaScript;Node.js;Py...
# 28792         20000000.0  C#;C++;Groovy;HTML/CSS;Java;JavaScript;Node.js...
# 12701         19200000.0                                         JavaScript
# 9609          17500000.0  Bash/Shell;Go;HTML/CSS;Java;JavaScript;Kotlin;...
# 5306          15000000.0                                             Python
# 12904         14411628.0                       C#;JavaScript;Node.js;Python
# 66489         12750000.0  Bash/Shell;Go;HTML/CSS;Java;JavaScript;Kotlin;...
# 47564         12500000.0           Go;HTML/CSS;JavaScript;Python;TypeScript

# %% [markdown]
# ### Grouping and Aggregating - Analyzing and Exploring Your Data

# %%
df['SalaryYearly'].median()
# Out:
# 56211.0

# %%
df[['CompTotal', 'SalaryYearly']].median()
# Out:
# CompTotal       67000.0
# SalaryYearly    56211.0
# dtype: float64

# %%
df.describe()
# Out:
#           CompTotal  SalaryYearly
# count  4.718300e+04  4.684400e+04
# mean   2.119407e+69  1.184262e+05
# std    4.603702e+71  5.272944e+05
# min    0.000000e+00  1.000000e+00
# 25%    1.600000e+04  2.702500e+04
# 50%    6.700000e+04  5.621100e+04
# 75%    1.400000e+05  1.000000e+05
# max    1.000000e+74  4.524131e+07

# %%
df['DatabaseHaveWorkedWith'].count()
# Out:
# 69546

# %%
df['DatabaseHaveWorkedWith'].value_counts().head(5)
# Out:
# MySQL                   4777
# Microsoft SQL Server    3823
# PostgreSQL              3537
# SQLite                  2191
# MongoDB                 1656
# Name: DatabaseHaveWorkedWith, dtype: int64

# %%
df['Country'].value_counts(normalize=True).head(20)
# Out:
# United States of America                                0.183224
# India                                                   0.125972
# Germany                                                 0.067415
# United Kingdom of Great Britain and Northern Ireland    0.053632
# Canada                                                  0.036098
# France                                                  0.032455
# Brazil                                                  0.027014
# Poland                                                  0.021633
# Netherlands                                             0.021237
# Italy                                                   0.019967
# Australia                                               0.019727
# Spain                                                   0.017797
# Russian Federation                                      0.017666
# Sweden                                                  0.014334
# ...

# %%
country_grp = df.groupby(['Country'])

# %%
country_grp.get_group('United States of America')
# Out:
#                                                    MainBranch  \
# ResponseId
# 40587                          I AM A DEVELOPER BY PROFESSION
# 9609        I AM NOT PRIMARILY A DEVELOPER, BUT I WRITE CO...
# 5306                           I AM A DEVELOPER BY PROFESSION
# 66489                          I AM A DEVELOPER BY PROFESSION
# 47564                          I AM A DEVELOPER BY PROFESSION
# ...                                                       ...
# 83401                          I AM A DEVELOPER BY PROFESSION
# 83413                          I AM A DEVELOPER BY PROFESSION
# 83415                             I CODE PRIMARILY AS A HOBBY
# 83427                          I AM A DEVELOPER BY PROFESSION
# 83430                             I CODE PRIMARILY AS A HOBBY
#
#                                                    Employment  \
# ResponseId
# 40587                                      Employed full-time
# 9609                                       Employed full-time
# ...

# %%
filt = df['Country'] == 'China'
df.loc[filt]['Age1stCode'].value_counts()
# Out:
# 18 - 24 years           374
# 11 - 17 years           252
# 5 - 10 years            177
# Younger than 5 years    110
# 25 - 34 years            85
# 35 - 44 years            19
# 45 - 54 years             7
# 55 - 64 years             3
# Older than 64 years       1
# Name: Age1stCode, dtype: int64

# %%
country_grp['Age1stCode'].value_counts()
# Out:
# Country      Age1stCode
# Afghanistan  18 - 24 years           19
#              Younger than 5 years    13
#              11 - 17 years           12
#              5 - 10 years             7
#              25 - 34 years            4
#                                      ..
# Zimbabwe     11 - 17 years            9
#              25 - 34 years            5
#              5 - 10 years             2
#              35 - 44 years            1
#              Older than 64 years      1
# Name: Age1stCode, Length: 992, dtype: int64

# %%
country_grp['Age1stCode'].value_counts().loc['China']
# Out:
# Age1stCode
# 18 - 24 years           374
# 11 - 17 years           252
# 5 - 10 years            177
# Younger than 5 years    110
# 25 - 34 years            85
# 35 - 44 years            19
# 45 - 54 years             7
# 55 - 64 years             3
# Older than 64 years       1
# Name: Age1stCode, dtype: int64

# %%
country_grp['SalaryYearly'].median().loc['China']
# Out:
# 34296.0

# %%
country_grp['SalaryYearly'].agg(['median', 'mean']).loc['United States of America']
# Out:
# median    125000.00000
# mean      262993.89848
# Name: United States of America, dtype: float64

# %%
filt = df['Country'] == 'India'
df.loc[filt]['LanguageHaveWorkedWith'].str.contains('Python').sum()
# Out:
# 5233

# %%
country_grp['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# Country
# Afghanistan                              20
# Albania                                  30
# Algeria                                  19
# Andorra                                   4
# Angola                                    5
#                                        ...
# Venezuela, Bolivarian Republic of...     43
# Viet Nam                                173
# Yemen                                     6
# Zambia                                   12
# Zimbabwe                                 17
# Name: LanguageHaveWorkedWith, Length: 181, dtype: int64

# %%
# what % of people from each country know python
country_respondents = df['Country'].value_counts().sort_index()
# country_respondents
know_python = country_grp['LanguageHaveWorkedWith'].apply(lambda x: x.str.contains('Python').sum())

know_python/country_respondents
# Out:
# Country
# Afghanistan                             0.307692
# Albania                                 0.410959
# Algeria                                 0.413043
# Andorra                                 0.333333
# Angola                                  0.185185
#                                           ...
# Venezuela, Bolivarian Republic of...    0.413462
# Viet Nam                                0.448187
# Yemen                                   0.300000
# Zambia                                  0.545455
# Zimbabwe                                0.472222
# Length: 181, dtype: float64

# %%
python_df = pd.concat([country_respondents, know_python], axis='columns', sort=False)
python_df.rename(columns={'Country': 'NumRespondents', 'LanguageHaveWorkedWith': 'NumKnowsPython'}, inplace=True)
python_df
# Out:
#                                       NumRespondents  NumKnowsPython
# Afghanistan                                       65              20
# Albania                                           73              30
# Algeria                                           46              19
# Andorra                                           12               4
# Angola                                            27               5
# ...                                              ...             ...
# Venezuela, Bolivarian Republic of...             104              43
# Viet Nam                                         386             173
# Yemen                                             20               6
# Zambia                                            22              12
# Zimbabwe                                          36              17
#
# [181 rows x 2 columns]

# %%
python_df['PctKnownsPython'] = python_df['NumKnowsPython'] / python_df['NumRespondents'] * 100
python_df
# Out:
#                                       NumRespondents  NumKnowsPython  \
# Afghanistan                                       65              20
# Albania                                           73              30
# Algeria                                           46              19
# Andorra                                           12               4
# Angola                                            27               5
# ...                                              ...             ...
# Venezuela, Bolivarian Republic of...             104              43
# Viet Nam                                         386             173
# Yemen                                             20               6
# Zambia                                            22              12
# Zimbabwe                                          36              17
#
#                                       PctKnownsPython
# Afghanistan                                 30.769231
# ...

# %%
python_df.sort_values(by='PctKnownsPython', ascending=False).head(20)
# Out:
#                    NumRespondents  NumKnowsPython  PctKnownsPython
# Tuvalu                          1               1       100.000000
# Sierra Leone                    2               2       100.000000
# Brunei Darussalam               1               1       100.000000
# Dominica                        1               1       100.000000
# Liechtenstein                   1               1       100.000000
# Burundi                         5               4        80.000000
# Namibia                        12               9        75.000000
# Burkina Faso                    4               3        75.000000
# Bahamas                         7               5        71.428571
# Qatar                          29              20        68.965517
# Liberia                         3               2        66.666667
# Saint Lucia                     3               2        66.666667
# Cuba                           34              22        64.705882
# ...

# %%
python_df.loc['Japan']
# Out:
# NumRespondents     429.000000
# NumKnowsPython     209.000000
# PctKnownsPython     48.717949
# Name: Japan, dtype: float64

# %% [markdown]
# ### Cleaning Data - Casting Datatypes and Handling Missing Values

# %%
df['YearsCode'].head(10)
# Out:
# ResponseId
# 66911     1
# 65400     7
# 40587    37
# 28792    11
# 12701     5
# 9609     25
# 5306     25
# 12904     6
# 66489     5
# 47564    24
# Name: YearsCode, dtype: object

# %%
# df['YearsCode'].mean()
# df['YearsCode'] = df['YearsCode'].astype(float)
df['YearsCode'].unique()
# Out:
# array(['1', '7', '37', '11', '5', '25', '6', '24', '30', '28', '13', '35',
#        '20', '33', '12', nan, '14', '38', '17', '8', '16', '10', '15',
#        '22', '9', '4', '21', '32', '19', '26', '18', '45', '3', '31',
#        '23', 'Less than 1 year', '2', '36', '27', '39', '46', '44', '34',
#        '43', '40', '29', 'More than 50 years', '41', '47', '50', '42',
#        '49', '48'], dtype=object)

# %%
df['YearsCode'].replace('Less than 1 year', 0, inplace=True)
df['YearsCode'].replace('More than 50 years', 51, inplace=True)

# %%
df['YearsCode'] = df['YearsCode'].astype(float)
df['YearsCode'].mean()
# Out:
# 12.338200169032717

# %% [markdown]
# ### Working with Dates and Time Series Data

# %%
eth_df = pd.read_csv('data/ETH_1h.csv')
eth_df.head()
# Out:
#                Date  Symbol    Open    High     Low   Close      Volume
# 0  2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1  2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2  2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3  2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4  2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %%
eth_df.loc[0, 'Date']
# Out:
# '2020-03-13 08-PM'

# %%
# https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior
eth_df['Date'] = pd.to_datetime(eth_df['Date'], format='%Y-%m-%d %I-%p')
eth_df['Date'].head()
# Out:
# 0   2020-03-13 20:00:00
# 1   2020-03-13 19:00:00
# 2   2020-03-13 18:00:00
# 3   2020-03-13 17:00:00
# 4   2020-03-13 16:00:00
# Name: Date, dtype: datetime64[ns]

# %%
eth_df.loc[0, 'Date'].day_name()
# Out:
# 'Friday'

# %%
from datetime import datetime
d_parser = lambda x: datetime.strptime(x, '%Y-%m-%d %I-%p')
eth_df2 = pd.read_csv('data/ETH_1h.csv', parse_dates=['Date'], date_parser=d_parser)
eth_df2.head()
# Out:
#                  Date  Symbol    Open    High     Low   Close      Volume
# 0 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %%
eth_df2['Date'].dt.day_name()
# Out:
# 0          Friday
# 1          Friday
# 2          Friday
# 3          Friday
# 4          Friday
#            ...
# 23669    Saturday
# 23670    Saturday
# 23671    Saturday
# 23672    Saturday
# 23673    Saturday
# Name: Date, Length: 23674, dtype: object

# %%
eth_df2['DayOfWeek'] = eth_df2['Date'].dt.day_name()
eth_df2
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#       DayOfWeek
# ...

# %%
eth_df2['Date'].min()
# Out:
# Timestamp('2017-07-01 11:00:00')

# %%
eth_df2['Date'].max()
# Out:
# Timestamp('2020-03-13 20:00:00')

# %%
eth_df2['Date'].max() - eth_df2['Date'].min()
# Out:
# Timedelta('986 days 09:00:00')

# %%
filt = (eth_df2['Date'] >= pd.to_datetime('2019-01-01')) & (eth_df2['Date'] < pd.to_datetime('2020-01-01'))
eth_df2.loc[filt]
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 1749  2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 1750  2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 1751  2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 1752  2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 1753  2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                   ...     ...     ...     ...     ...     ...         ...
# 10504 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 10505 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 10506 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 10507 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 10508 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#       DayOfWeek
# ...

# %%
eth_df2.set_index('Date', inplace=True)

# %%
eth_df2.loc['2019']
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                     ...     ...     ...     ...     ...         ...
# 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#                     DayOfWeek
# Date
# 2019-12-31 23:00:00   Tuesday
# ...

# %%
eth_df2.loc['2020-01':'2020-02']
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-02-29 23:00:00  ETHUSD  223.35  223.58  216.83  217.31  1927939.88
# 2020-02-29 22:00:00  ETHUSD  223.48  223.59  222.14  223.35   535998.57
# 2020-02-29 21:00:00  ETHUSD  224.63  225.14  222.74  223.48   561158.03
# 2020-02-29 20:00:00  ETHUSD  225.31  225.33  223.50  224.63   511648.65
# 2020-02-29 19:00:00  ETHUSD  225.09  225.85  223.87  225.31  1250856.20
# ...                     ...     ...     ...     ...     ...         ...
# 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
# 2020-01-01 00:00:00  ETHUSD  128.54  128.54  128.12  128.34   245119.91
#
#                      DayOfWeek
# Date
# 2020-02-29 23:00:00   Saturday
# ...

# %%
eth_df2.loc['2020-01-01']['High'].max()
# Out:
# 132.68

# %%
highs = eth_df2['High'].resample('D').max()
highs
# Out:
# Date
# 2017-07-01    279.99
# 2017-07-02    293.73
# 2017-07-03    285.00
# 2017-07-04    282.83
# 2017-07-05    274.97
#                ...
# 2020-03-09    208.65
# 2020-03-10    206.28
# 2020-03-11    202.98
# 2020-03-12    195.64
# 2020-03-13    148.00
# Freq: D, Name: High, Length: 987, dtype: float64

# %%
# %matplotlib inline

# %%
highs.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
eth_df2.resample('W').mean()
# Out:
#                   Open        High         Low       Close        Volume
# Date
# 2017-07-02  268.066486  271.124595  264.819730  268.202162  2.185035e+06
# 2017-07-09  261.337024  262.872917  259.186190  261.062083  1.337349e+06
# 2017-07-16  196.193214  199.204405  192.722321  195.698393  2.986756e+06
# 2017-07-23  212.351429  215.779286  209.126310  212.783750  4.298593e+06
# 2017-07-30  203.496190  205.110357  201.714048  203.309524  1.581729e+06
# ...                ...         ...         ...         ...           ...
# 2020-02-16  255.021667  257.255238  252.679762  255.198452  2.329087e+06
# 2020-02-23  265.220833  267.263690  262.948512  265.321905  1.826094e+06
# 2020-03-01  236.720536  238.697500  234.208750  236.373988  2.198762e+06
# 2020-03-08  229.923571  231.284583  228.373810  229.817619  1.628910e+06
# 2020-03-15  176.937521  179.979487  172.936239  176.332821  4.259828e+06
#
# [142 rows x 5 columns]

# %%
eth_df2.resample('W').agg({'Close': 'mean', 'High': 'max', 'Low': 'min', 'Volume': 'sum'})
# Out:
#                  Close    High     Low        Volume
# Date
# 2017-07-02  268.202162  293.73  253.23  8.084631e+07
# 2017-07-09  261.062083  285.00  231.25  2.246746e+08
# 2017-07-16  195.698393  240.33  130.26  5.017750e+08
# 2017-07-23  212.783750  249.40  153.25  7.221637e+08
# 2017-07-30  203.309524  229.99  178.03  2.657305e+08
# ...                ...     ...     ...           ...
# 2020-02-16  255.198452  290.00  216.31  3.912867e+08
# 2020-02-23  265.321905  287.13  242.36  3.067838e+08
# 2020-03-01  236.373988  278.13  209.26  3.693920e+08
# 2020-03-08  229.817619  253.01  196.00  2.736569e+08
# 2020-03-15  176.332821  208.65   90.00  4.983998e+08
#
# [142 rows x 4 columns]
